# %%
# import base64
# def get_image_data(res_path):
#     with open(res_path, "rb") as img_file:
#         encoded_string = base64.b64encode(img_file.read()).decode("utf-8")
#     print(encoded_string)   # Copy đoạn này vào code chính

# get_image_data("icon/countdown.png")

# %%
CLOCK_BASE64 = "..."
COME_BASE64 = "..."
OUT_BASE64 = "..."
HUNGRY_BASE64 = "..."
COUNTDOWN_BASE64 = "..."
